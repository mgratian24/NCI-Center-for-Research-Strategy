# %% [markdown]
# # Brief Project Name
#
# ## N. Notebook Name
# *Use this to give the notebook a specific name to differentiate it from other work in this project. N should reflect the order the ordering of the notebooks in this project. E.g., 1 is the first notebook that should be run.*
#
# Date: MM/DD/YY
#
# Analyst:
#
# QAer:
#
# **Notebook Goal(s):** *The goal(s) of this noteboook and how it fits into the bigger picture of the project*
# - The goal of this notebook is to do x in order to do y...
#
# **Inputs:** *The files that are read into the Notebook in order for it to run*
# - Input Filepath 1:
#     - Brief description of the file
#     - Source of file
# - Input Filepath 2:
#     - Brief description of the file
#     - Source of file
#
# **Outputs:** *The files that are generated by the Notebook*
# - Output Filepath 1:
#     - Brief description of the file
# - Output Filepath 2:
#     - Brief description of the file

# %% [markdown]
# ## Import Packages
#
# Import all packages that are used in the Notebook here.

# %%
# import...

# %% [markdown]
# ## Definitions (Optional)
#
# Add in any definitions you might use in your code here. For example, a list of years you might reference later when filtering your tables to a specific subset of years.

# %%
# Fill in

# %% [markdown]
# ## Read in Data
#
# Read in all data inputs. This should match all files listed in the Notebook description header.

# %%
# Fill in

# %% [markdown]
# ## Functions
#
# Add any functions you will use to process your data.
#
# If a more complicated function, potentially include cell blocks that test different inputs and the resulting function output.

# %%
# Fill in

# %% [markdown]
# ## Dataset Development
# **Preprocess, Merge, Filter, and/or Split Data.**
#
# - Merge separate datasets as needed
# - Add any additional columns or derived values to the data
# - Reduce the input data down to the specific fields of interest or document if these steps were done in  Excel, etc.
# - Split into any distinct  for the final analysis

# %%
# Fill in

# %% [markdown]
# ## Analyze and Extract Insights from Data
#
# **Further split into subsections as needed.**

# %%
# Fill in

# %% [markdown]
# ## Save Outputs

# %%
# Fill in
